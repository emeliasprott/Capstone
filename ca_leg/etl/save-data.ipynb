# %%
import psycopg2
import pandas as pd
from tqdm import tqdm

# %%
DB_CONFIG = {
    'database': 'legislation_db',
    'host': "localhost",
    'user': "legislation",
    'password': "password",
    'port': 5432,
}
years = [i for i in range(1989, 2027, 2) if i != 2011]

# %%
def table_name(table):
    return f"legislation_db.{table}"

TABLE_DEFS = {
    'bill_analysis_tbl': {
        'table_name': table_name('bill_analysis_tbl'),
        'columns': [
            "analysis_id",
            "bill_id",
            "house",
            "analysis_type",
            "committee_code",
            "committee_name",
            "amendment_author",
            "analysis_date",
            "amendment_date",
            'source_doc',
            "released_floor",
        ]
    },
    'bill_detail_vote_tbl': {
        'table_name': table_name('bill_detail_vote_tbl'),
        'columns': [
            "bill_id",
            "location_code",
            "legislator_name",
            "vote_date_time",
            "vote_date_seq",
            "vote_code",
            "motion_id",
            "member_order",
            "session_date",
        ]
    },
    'bill_history_tbl': {
        'table_name': table_name('bill_history_tbl'),
        'columns': [
            "bill_id",
            "bill_history_id",
            "action_date",
            "action_",
            "action_sequence",
            'action_code',
            'action_status',
            'primary_location',
            'secondary_location',
            'end_status',
        ]
    },
    'bill_motion_tbl': {
        'table_name': table_name('bill_motion_tbl'),
        'columns': [
            'motion_id',
            'motion_text',
        ]
    },
    'bill_summary_vote_tbl': {
        'table_name': table_name('bill_summary_vote_tbl'),
        'columns': [
            'bill_id',
            'location_code',
            'vote_date_time',
            'motion_id',
            'ayes',
            'noes',
            'abstain',
            'vote_result'
        ]
    },
    'bill_tbl': {
        'table_name': table_name('bill_tbl'),
        'columns': [
            "bill_id",
            "session_year",
            "session_num",
            "measure_num",
            "measure_state",
            "chapter_year",
            "chapter_type",
            "chapter_session_num",
            "chapter_num",
            "latest_bill_version_id",
            "current_location",
            "current_status",
        ]
    },
    'bill_version_author_tbl': {
        'table_name': table_name('bill_version_author_tbl'),
        'columns': [
            'bill_version_id',
            'type',
            'house',
            'name',
            'contribution',
            'committee_members',
            'primary_author_flg'
        ]
    },
    'bill_version_tbl': {
        'table_name': table_name('bill_version_tbl'),
        'columns': [
            "bill_version_id",
            "bill_id",
            "version_num",
            "bill_version_action_date",
            "bill_version_action",
            "request_num",
            "subject",
            "vote_required",
            "appropriation",
            "fiscal_committee",
            "local_program",
            "substantive_changes",
            "urgency",
            "taxlevy",
            'bill_xml'
        ]
    },
    'codes_tbl': {
        'table_name': table_name('codes_tbl'),
        'columns': ['code', 'title']
    }
}

# %%
def db_connect():
    return psycopg2.connect(**DB_CONFIG)

# %%
def pull_data(table_name, year, columns):
    partition_name = f"{table_name}_{year}"
    col_str = ', '.join(columns)
    query = f"SELECT {col_str} FROM {partition_name};"
    try:
        conn = db_connect()
        cursor = conn.cursor()
        cursor.execute(query)
        rows = cursor.fetchall()
        data = pd.DataFrame(rows)
        if data.empty:
            return 'missing'
        data.columns = columns
        return data
    except:
        return 'missing'
    finally:
        if 'cursor' in locals():
            cursor.close()
        if 'conn' in locals():
            conn.close()

# %%
def get_table_data(table_key, year):
    if table_key not in TABLE_DEFS:
        raise ValueError(f"Unknown table key: {table_key}")

    table_info = TABLE_DEFS[table_key]
    table_name = table_info['table_name']
    table_columns = table_info['columns']
    data = pull_data(table_name, year, table_columns)
    if isinstance(data, pd.DataFrame):
        return data
    else:
        return 'missing'

def get_all_years(table_key):
    all_data = []
    for year in years:
        data = get_table_data(table_key, year)
        if isinstance(data, pd.DataFrame):
            data['year'] = year
            all_data.append(data)
    if all_data:
        return pd.concat(all_data)
    else:
        return pd.DataFrame()

# %%
for table_key in tqdm(TABLE_DEFS.keys()):
    data = get_all_years(table_key)
    file_name = f'../legislation_data/{table_key}.csv'
    data.to_csv(file_name, index=False)
# Out:
#  11%|█         | 1/9 [00:03<00:25,  3.24s/it]/var/folders/z8/jkjxx5pj447bytbqv8pkw9nh0000gn/T/ipykernel_16957/168532101.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(all_data)
# 100%|██████████| 9/9 [00:59<00:00,  6.64s/it]

# %%
versions = pd.read_csv('../legislation_data/bill_version_tbl.csv')
versions
# Out:
#          bill_version_id          bill_id  version_num  \
# 0       19890SB147095CHP  198919900SB1470           95
# 1        19890SB86895CHP   198919900SB868           95
# 2        19890SB75496CHP   198919900SB754           96
# 3        19890SB68696CHP   198919900SB686           96
# 4        19890SB57694CHP   198919900SB576           94
# ...                  ...              ...          ...
# 246878     20251SB499INT     202520261SB4           99
# 246879    20251SCR199INT    202520261SCR1           99
# 246880    20251SCR299INT    202520261SCR2           99
# 246881     20251SR198ENR     202520261SR1           98
# 246882     20251SR199INT     202520261SR1           99
#
#        bill_version_action_date bill_version_action  request_num  \
# 0                    1989-09-08           Chaptered          NaN
# 1                    1989-09-08           Chaptered          NaN
# 2                    1989-09-08           Chaptered          NaN
# 3                    1989-09-08           Chaptered          NaN
# 4                    1989-09-08           Chaptered          NaN
# ...                         ...                 ...          ...
# 246878               2025-01-20          Introduced          NaN
# 246879               2024-12-02          Introduced          NaN
# 246880               2025-01-23          Introduced          NaN
# 246881               2025-01-10            Enrolled          NaN
# 246882               2025-01-07          Introduced          NaN
#
#                                                   subject vote_required  \
# 0                 Public works contracts:  change orders.           NaN
# 1                        Medi-Cal:  submission of claims.           NaN
# 2       Escrow funds:  deposit in industrial loan comp...           NaN
# 3                             STRS:  payment of benefits.           NaN
# 4                                       Nursing shortage.           NaN
# ...                                                   ...           ...
# 246878                                Budget Act of 2024.      Majority
# 246879  2025–26 First Extraordinary Session: Joint Rul...           NaN
# 246880  2025–26 First Extraordinary Session of the Leg...           NaN
# 246881                                                NaN           NaN
# 246882                                                NaN           NaN
#
#        appropriation fiscal_committee local_program  substantive_changes  \
# 0                NaN              NaN           NaN                  NaN
# 1                NaN              NaN           NaN                  NaN
# 2                NaN              NaN           NaN                  NaN
# 3                NaN              NaN           NaN                  NaN
# 4                NaN              NaN           NaN                  NaN
# ...              ...              ...           ...                  ...
# 246878           Yes              Yes            No                  NaN
# 246879           NaN               No           NaN                  NaN
# 246880           NaN               No           NaN                  NaN
# 246881           NaN              NaN           NaN                  NaN
# 246882           NaN              NaN           NaN                  NaN
#
#        urgency taxlevy                   bill_xml  year
# 0          NaN     NaN  BILL_VERSION_TBL_1348.lob  1989
# 1          NaN     NaN  BILL_VERSION_TBL_1349.lob  1989
# 2          NaN     NaN  BILL_VERSION_TBL_1350.lob  1989
# 3          NaN     NaN  BILL_VERSION_TBL_1351.lob  1989
# 4          NaN     NaN  BILL_VERSION_TBL_1352.lob  1989
# ...        ...     ...                        ...   ...
# 246878     Yes      No  BILL_VERSION_TBL_2643.lob  2025
# 246879     NaN     NaN  BILL_VERSION_TBL_2644.lob  2025
# 246880     NaN     NaN  BILL_VERSION_TBL_2645.lob  2025
# 246881     NaN     NaN  BILL_VERSION_TBL_2646.lob  2025
# 246882     NaN     NaN  BILL_VERSION_TBL_2647.lob  2025
#
# [246883 rows x 16 columns]

# %%
versions.bill_version_action.unique()
# Out:
# array(['Chaptered', 'Amended Assembly', 'Enrolled', 'Introduced',
#        'Amended Senate', 'Proposed', 'Amended', 'Vetoed'], dtype=object)

# %%
analysis = pd.read_csv('../legislation_data/bill_analysis_tbl.csv')
# Out:
# /var/folders/z8/jkjxx5pj447bytbqv8pkw9nh0000gn/T/ipykernel_71806/1029988857.py:1: DtypeWarning: Columns (4,6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   analysis = pd.read_csv('../legislation_data/bill_analysis_tbl.csv')

# %%
analysis
# Out:
#         analysis_id        bill_id house analysis_type committee_code  \
# 0             46669  199319940AB10     A          CMTE            NaN
# 1             46670  199319940AB10     S          CMTE            NaN
# 2             46671  199319940AB10     S          CMTE            NaN
# 3             46672  199319940AB10     S          CMTE            NaN
# 4             46673  199319940AB10     S          CMTE            NaN
# ...             ...            ...   ...           ...            ...
# 328038       382101   202520260SR7     S         FLOOR           CZ09
# 328039       382102   202520260SR9     S         FLOOR           CZ09
# 328040       382120   202520261AB4     S         FLOOR           CZ09
# 328041       382107   202520261AB4     A           ATR           CZ01
# 328042       382108   202520261AB5     A           ATR           CZ01
#
#                  committee_name amendment_author        analysis_date  \
# 0            Assembly Committee              NaN           1993-02-08
# 1              Senate Committee              NaN           1993-03-25
# 2              Senate Committee              NaN           1993-03-25
# 3              Senate Committee              NaN           1993-07-07
# 4              Senate Committee              NaN           1993-09-08
# ...                         ...              ...                  ...
# 328038      Sen. Floor Analyses        OchoaBogh  2025-01-22 00:00:00
# 328039      Sen. Floor Analyses         Gonzalez  2025-01-22 00:00:00
# 328040      Sen. Floor Analyses          Gabriel  2025-01-23 00:00:00
# 328041  ASSEMBLY FLOOR ANALYSIS          GABRIEL  2025-01-22 00:00:00
# 328042  ASSEMBLY FLOOR ANALYSIS          GABRIEL  2025-01-22 00:00:00
#
#              amendment_date               source_doc released_floor  year
# 0                       NaN  <memory at 0x10919b100>              Y  1993
# 1                       NaN  <memory at 0x10919b280>              Y  1993
# 2                       NaN  <memory at 0x10919af80>              Y  1993
# 3                       NaN  <memory at 0x10919b1c0>              Y  1993
# 4                       NaN  <memory at 0x10919b340>              Y  1993
# ...                     ...                      ...            ...   ...
# 328038  2025-01-06 00:00:00  <memory at 0x160a58f40>              Y  2025
# 328039  2025-01-07 00:00:00  <memory at 0x160a59000>              Y  2025
# 328040  2025-01-20 00:00:00  <memory at 0x160a590c0>              Y  2025
# 328041  2025-01-20 00:00:00  <memory at 0x160a59180>              Y  2025
# 328042  2025-01-20 00:00:00  <memory at 0x160a59240>              Y  2025
#
# [328043 rows x 12 columns]

# %%
conn = psycopg2.connect(**DB_CONFIG)
cursor = conn.cursor()
query = "SELECT lo_read(source_doc) FROM legislation_db.bill_analysis_tbl_2025;"
rows = cursor.execute(query)
data = pd.DataFrame(rows)
data
# Out:
# ---------------------------------------------------------------------------
# UndefinedFunction                         Traceback (most recent call last)
# Cell In[11], line 4
#       2 cursor = conn.cursor()
#       3 query = "SELECT lo_read(source_doc) FROM legislation_db.bill_analysis_tbl_2025;"
# ----> 4 rows = cursor.execute(query)
#       5 data = pd.DataFrame(rows)
#       6 data
#
# UndefinedFunction: function lo_read(bytea) does not exist
# LINE 1: SELECT lo_read(source_doc) FROM legislation_db.bill_analysis...
#                ^
# HINT:  No function matches the given name and argument types. You might need to add explicit type casts.

# %%
[a for a in analysis['bill_id'].unique() if a in versions['bill_id'].unique()]
# Out:
# ['199319940AB10',
#  '199319940AB11',
#  '199319940AB13',
#  '199319940AB14',
#  '199319940AB17',
#  '199319940AB18',
#  '199319940AB19',
#  '199319940AB21',
#  '199319940AB25',
#  '199319940AB28',
#  '199319940AB31',
#  '199319940AB32',
#  '199319940AB33',
#  '199319940AB34',
#  '199319940AB35',
#  '199319940AB36',
#  '199319940AB37',
#  '199319940AB39',
#  '199319940AB40',
#  '199319940AB41',
#  '199319940AB42',
#  '199319940AB43',
#  '199319940AB46',
#  '199319940AB47',
#  '199319940AB48',
#  '199319940AB49',
#  '199319940AB5',
#  '199319940AB6',
#  '199319940AB7',
#  '199319940AB8',
#  '199319941AB13',
#  '199319941AB19',
#  '199319941AB1',
#  '199319941AB25',
#  '199319941AB27',
#  '199319941AB29',
#  '199319941AB30',
#  '199319941AB36',
#  '199319941AB3',
#  '199319941AB45',
#  '199319941AB49',
#  '199319941AB4',
#  '199319941AB8',
#  '199319940ACA17',
#  '199319940ACA37',
#  '199319940ACA46',
#  '199319940ACA8',
#  '199319940ACR10',
#  '199319940ACR11',
#  '199319940ACR12',
#  '199319940ACR13',
#  '199319940ACR15',
#  '199319940ACR17',
#  '199319940ACR18',
#  '199319940ACR19',
#  '199319940ACR20',
#  '199319940ACR21',
#  '199319940ACR22',
#  '199319940ACR24',
#  '199319940ACR25',
#  '199319940ACR26',
#  '199319940ACR27',
#  '199319940ACR28',
#  '199319940ACR2',
#  '199319940ACR30',
#  '199319940ACR32',
#  '199319940ACR33',
#  '199319940ACR34',
#  '199319940ACR36',
#  '199319940ACR38',
#  '199319940ACR39',
#  '199319940ACR3',
#  '199319940ACR41',
#  '199319940ACR42',
#  '199319940ACR43',
#  '199319940ACR44',
#  '199319940ACR46',
