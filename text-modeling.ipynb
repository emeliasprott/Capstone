# %%
import pandas as pd
import re
import numpy as np
import warnings
from tqdm import tqdm
from sentence_transformers import SentenceTransformer

warnings.filterwarnings('ignore', category=pd.errors.SettingWithCopyWarning)

# %%
bill_history = pd.read_csv('ca_leg/legislation_data/bill_history_tbl.csv', dtype={'action_status': str, 'primary_location': str, 'secondary_location': str, 'end_status': str})

# %%
bill_history.columns
# Out:
# Index(['bill_id', 'bill_history_id', 'action_date', 'action_',
#        'action_sequence', 'action_code', 'action_status', 'primary_location',
#        'secondary_location', 'end_status', 'year'],
#       dtype='object')

# %%
bill_history
# Out:
#                 bill_id  bill_history_id action_date  \
# 0        199920000AB630          1388441  1999-02-19
# 1         199920000ACA9          1388442  2000-11-30
# 2         199920000ACA9          1388443  1999-05-11
# 3         199920000ACA9          1388444  1999-04-27
# 4         199920000ACA9          1388445  1999-04-22
# ...                 ...              ...         ...
# 1086867   202520261SCR2        117393745  2025-02-04
# 1086868   202520261SCR2        117393743  2025-01-23
# 1086869    202520261SR1        117390240  2025-01-07
# 1086870    202520261SR1        117390241  2025-01-09
# 1086871    202520261SR1        117390242  2025-01-09
#
#                                                    action_  action_sequence  \
# 0                              Read first time.  To print.              NaN
# 1                   From committee without further action.              NaN
# 2        In committee:  Set first hearing.  Failed pass...              NaN
# 3                          Re-referred to Com. on  PUB. S.              NaN
# 4        From committee chair, with author's amendments...              NaN
# ...                                                    ...              ...
# 1086867                             Died on third reading.              3.0
# 1086868              Introduced. Referred to Com. on  RLS.              1.0
# 1086869              Introduced. Referred to Com. on  RLS.              1.0
# 1086870          From committee: Ordered to third reading.              2.0
# 1086871        Read. Adopted. (Ayes 24. Noes  9. Page 12.)              3.0
#
#          action_code action_status primary_location secondary_location  \
# 0                NaN           NaN              NaN                NaN
# 1                NaN           NaN              NaN                NaN
# 2                NaN           NaN              NaN                NaN
# 3                NaN           NaN              NaN                NaN
# 4                NaN           NaN              NaN                NaN
# ...              ...           ...              ...                ...
# 1086867        245.0       Applied           Senate              Floor
# 1086868          2.0       Applied           Senate          Committee
# 1086869          2.0       Applied           Senate          Committee
# 1086870         12.0       Applied           Senate              Floor
# 1086871        136.0       Applied           Senate               Desk
#
#                    end_status  year
# 0                         NaN  1999
# 1                         NaN  1999
# 2                         NaN  1999
# 3                         NaN  1999
# 4                         NaN  1999
# ...                       ...   ...
# 1086867                  Died  2025
# 1086868  In Committee Process  2025
# 1086869  In Committee Process  2025
# 1086870      In Floor Process  2025
# 1086871                Passed  2025
#
# [1086872 rows x 11 columns]

# %%
full = pd.read_csv('ca_leg/legislation_data/combined_table.csv', dtype={'current_location': str, 'current_status': str})

# %%
full.columns
# Out:
# Index(['bill_id_x', 'author_type', 'house', 'author_name', 'bill_version_id',
#        'bill_id_y', 'version_num', 'bill_version_action_date',
#        'bill_version_action', 'request_num', 'subject', 'vote_required',
#        'appropriation', 'fiscal_committee', 'local_program',
#        'substantive_changes', 'urgency', 'taxlevy', 'bill_xml', 'year_x',
#        'bill_id', 'session_year', 'session_num', 'measure_num',
#        'measure_state', 'chapter_year', 'chapter_type', 'chapter_session_num',
#        'chapter_num', 'latest_bill_version_id', 'current_location',
#        'current_status', 'year_y'],
#       dtype='object')

# %%
full
# Out:
#                bill_id_x         author_type     house   author_name  \
# 0        19990AB26893ENR         LEAD_AUTHOR  ASSEMBLY        Nakano
# 1        19990AB26893ENR            COAUTHOR  ASSEMBLY        Zettel
# 2        19990AB26893ENR            COAUTHOR    SENATE         Solis
# 3        19990AB51398AMD         LEAD_AUTHOR  ASSEMBLY  Strom-Martin
# 4        19990AB51398AMD            COAUTHOR  ASSEMBLY      Campbell
# ...                  ...                 ...       ...           ...
# 266710  20170SB115192CHP            COAUTHOR  ASSEMBLY        Chávez
# 266711  20170AB102799INT         LEAD_AUTHOR  ASSEMBLY        Acosta
# 266712  20170AB102799INT  PRINCIPAL_COAUTHOR    SENATE          Wilk
# 266713   20170SB61193CHP         LEAD_AUTHOR    SENATE         Allen
# 266714   20170SB61193CHP            COAUTHOR    SENATE     Hertzberg
#
#          bill_version_id        bill_id_y  version_num  \
# 0        19990AB26893ENR   199920000AB268         93.0
# 1        19990AB26893ENR   199920000AB268         93.0
# 2        19990AB26893ENR   199920000AB268         93.0
# 3        19990AB51398AMD   199920000AB513         98.0
# 4        19990AB51398AMD   199920000AB513         98.0
# ...                  ...              ...          ...
# 266710  20170SB115192CHP  201720180SB1151         92.0
# 266711  20170AB102799INT  201720180AB1027         99.0
# 266712  20170AB102799INT  201720180AB1027         99.0
# 266713   20170SB61193CHP   201720180SB611         93.0
# 266714   20170SB61193CHP   201720180SB611         93.0
#
#        bill_version_action_date bill_version_action  request_num  ...  \
# 0                    1999-07-15            Enrolled          NaN  ...
# 1                    1999-07-15            Enrolled          NaN  ...
# 2                    1999-07-15            Enrolled          NaN  ...
# 3                    1999-04-28    Amended Assembly          NaN  ...
# 4                    1999-04-28    Amended Assembly          NaN  ...
# ...                         ...                 ...          ...  ...
# 266710               2018-09-19           Chaptered          NaN  ...
# 266711               2017-02-16          Introduced          NaN  ...
# 266712               2017-02-16          Introduced          NaN  ...
# 266713               2017-10-04           Chaptered          NaN  ...
# 266714               2017-10-04           Chaptered          NaN  ...
#
#        measure_num     measure_state chapter_year chapter_type  \
# 0              268         Chaptered       1999.0          CHP
# 1              268         Chaptered       1999.0          CHP
# 2              268         Chaptered       1999.0          CHP
# 3              513  Amended Assembly          NaN          NaN
# 4              513  Amended Assembly          NaN          NaN
# ...            ...               ...          ...          ...
# 266710        1151         Chaptered       2018.0          CHP
# 266711        1027         Chaptered       2017.0          CHP
# 266712        1027         Chaptered       2017.0          CHP
# 266713         611         Chaptered       2017.0          CHP
# 266714         611         Chaptered       2017.0          CHP
#
#        chapter_session_num  chapter_num latest_bill_version_id  \
# 0                      0.0        193.0        19990AB26892CHP
# 1                      0.0        193.0        19990AB26892CHP
# 2                      0.0        193.0        19990AB26892CHP
# 3                      NaN          NaN        19990AB51397AMD
# 4                      NaN          NaN        19990AB51397AMD
# ...                    ...          ...                    ...
# 266710                 0.0        564.0       20170SB115192CHP
# 266711                 0.0        205.0       20170AB102796CHP
# 266712                 0.0        205.0       20170AB102796CHP
# 266713                 0.0        485.0        20170SB61193CHP
# 266714                 0.0        485.0        20170SB61193CHP
#
#        current_location current_status  year_y
# 0                   NaN            NaN    1999
# 1                   NaN            NaN    1999
# 2                   NaN            NaN    1999
# 3                   NaN            NaN    1999
# 4                   NaN            NaN    1999
# ...                 ...            ...     ...
# 266710              NaN      Chaptered    2017
# 266711              NaN      Chaptered    2017
# 266712              NaN      Chaptered    2017
# 266713              NaN      Chaptered    2017
# 266714              NaN      Chaptered    2017
#
# [266715 rows x 33 columns]

# %% [markdown]
# authors and versions

# %%
bill_votes = pd.read_csv('ca_leg/legislation_data/bill_detail_vote_tbl.csv', parse_dates=['session_date'])

# %%
bill_votes.columns
# Out:
# Index(['bill_id', 'location_code', 'legislator_name', 'vote_date_time',
#        'vote_date_seq', 'vote_code', 'motion_id', 'member_order',
#        'session_date', 'year'],
#       dtype='object')

# %%
bill_votes
# Out:
#                  bill_id location_code     legislator_name  \
# 0        199920000AB1387        AFLOOR                 Cox
# 1        199920000AB1387        AFLOOR             Cunneen
# 2        199920000AB1387        AFLOOR               Davis
# 3        199920000AB1387        AFLOOR           Dickerson
# 4        199920000AB1387        AFLOOR             Ducheny
# ...                  ...           ...                 ...
# 7445020    202520260SCR9          CX20               Irwin
# 7445021    202520260SCR9          CX20               Krell
# 7445022    202520260SCR9          CX20               Patel
# 7445023    202520260SCR9          CX20  Michelle Rodriguez
# 7445024    202520260SCR9          CX20             Sanchez
#
#               vote_date_time  vote_date_seq vote_code  motion_id  \
# 0        1999-09-01 13:16:00           1011       NOE     107178
# 1        1999-09-01 13:16:00           1011       NOE     107178
# 2        1999-09-01 13:16:00           1011       AYE     107178
# 3        1999-09-01 13:16:00           1011       NOE     107178
# 4        1999-09-01 13:16:00           1011       AYE     107178
# ...                      ...            ...       ...        ...
# 7445020  2025-02-10 00:00:00              1       AYE     147493
# 7445021  2025-02-10 00:00:00              1       AYE     147493
# 7445022  2025-02-10 00:00:00              1       AYE     147493
# 7445023  2025-02-10 00:00:00              1       AYE     147493
# 7445024  2025-02-10 00:00:00              1       AYE     147493
#
#          member_order session_date  year
# 0                 NaN          NaT  1999
# 1                 NaN          NaT  1999
# 2                 NaN          NaT  1999
# 3                 NaN          NaT  1999
# 4                 NaN          NaT  1999
# ...               ...          ...   ...
# 7445020           6.0   2025-02-10  2025
# 7445021           7.0   2025-02-10  2025
# 7445022           8.0   2025-02-10  2025
# 7445023           9.0   2025-02-10  2025
# 7445024          10.0   2025-02-10  2025
#
# [7445025 rows x 10 columns]

# %%
bill_summary = pd.read_csv('ca_leg/legislation_data/bill_summary_vote_tbl.csv')

# %%
bill_summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 bill_summary
#
# NameError: name 'bill_summary' is not defined

# %%
locations = pd.read_csv('ca_leg/legislation_data/committee_codes.csv')

# %%
locations.columns
# Out:
# Index(['committee_code', 'committee_name'], dtype='object')

# %%
clean_coms = []
for i, row in locations.iterrows():
    if row['committee_code'].startswith('CZ'):
        continue
    name = row['committee_name']
    if name.startswith('Sen.'):
        cname = re.sub(r'Sen. ', 'Senate ', name).lower()
    if row['committee_code'].startswith('CX'):
        if name.lower().startswith('assembly'):
            cname = name.lower()
        else:
            cname = 'assembly ' + name.lower()
# Out:
#     committee_code                                     committee_name
# 0             CZ09                                Sen. Floor Analyses
# 1             CS61                                Sen. Appropriations
# 2             CS69                Sen. Banking, Finance and Insurance
# 3             CS71          Sen. Energy, Utilities and Communications
# 4             CS59                    Sen. Transportation and Housing
# ..             ...                                                ...
# 139           CX38             Assembly Military and Veterans Affairs
# 140           CS66  Senate Committee on Military and Veterans Affairs
# 141           CX23         Assembly Committee on Utilities and Energy
# 142           CX04                                 Assembly Elections
# 143           CS66    Senate Committee on Military & Veterans Affairs
#
# [144 rows x 2 columns]

# %%
bill_motions = pd.read_csv('ca_leg/legislation_data/bill_motion_tbl.csv')

# %%
politicians = pd.read_csv('ca_leg/legislation_data/politicians.csv')

# %%
politicians.columns
# Out:
# Index(['committee_clean', 'position', 'Occupation', 'Party', 'District No.',
#        'Seat No.', 'Term', 'Last', 'full_name', 'chamber'],
#       dtype='object')

# %% [markdown]
# legislators and committees

# %%
lobbying = pd.read_csv('calaccess/lobbying_clean2.csv', dtype={'PAYEE_NAMS': str, 'BAKREF_TID': str})

# %%
lobbying.columns
# Out:
# Index(['FILING_ID', 'FIRM_NAME', 'AMEND_ID', 'LINE_ITEM', 'REC_TYPE',
#        'FORM_TYPE', 'TRAN_ID', 'RECSUBTYPE', 'ENTITY_CD', 'PAYEE_NAML',
#        'PAYEE_NAMF', 'PAYEE_NAMT', 'PAYEE_NAMS', 'PAYEE_CITY', 'PAYEE_ST',
#        'PAYEE_ZIP4', 'CREDCARDCO', 'BENE_NAME', 'BENE_POSIT', 'BENE_AMT',
#        'EXPN_DSCR', 'EXPN_DATE', 'AMOUNT', 'MEMO_CODE', 'MEMO_REFNO',
#        'BAKREF_TID', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'clean_beneficiary'],
#       dtype='object')

# %%
expend_assembly = pd.read_csv('calaccess/expend_assembly_matched.csv', dtype={'TargetPropositionName': str})

# %%
expend_assembly.columns
# Out:
# Index(['TargetCandidateName', 'TargetCandidateOffice', 'TargetPropositionName',
#        'ExpenderPosition', 'ExpenderName', 'ExpenderID', 'Amount',
#        'ExpenditureDscr', 'PayeeName', 'DateStart', 'DateEnd', 'DateRange',
#        'year', 'term_x', 'matched_target_name', 'term_y', 'politician',
#        'committee', 'position', 'committee_clean', 'Occupation', 'Party',
#        'District No.', 'Seat No.', 'Term', 'First', 'Last', 'Position',
#        'full_name', 'target_name'],
#       dtype='object')

# %%
expend_senate = pd.read_csv('calaccess/expend_senate_matched.csv', dtype={'TargetPropositionName': str})

# %%
expend_senate.columns
# Out:
# Index(['TargetCandidateName', 'TargetCandidateOffice', 'TargetPropositionName',
#        'ExpenderPosition', 'ExpenderName', 'ExpenderID', 'Amount',
#        'ExpenditureDscr', 'PayeeName', 'DateStart', 'DateEnd', 'DateRange',
#        'matched_target_name', 'term', 'politician', 'committee', 'position',
#        'committee_clean', 'Name', 'Occupation', 'Party', 'District No.',
#        'Seat No.', 'Phone', 'Counties', 'pages', 'Last', 'Term', 'full_name'],
#       dtype='object')

# %%
bill_text = pd.read_csv('ca_leg/legislation_data/bill_text.csv')

# %%
bill_text.columns
# Out:
# Index(['bill_id', 'title', 'general_subject', 'digest_text', 'content'], dtype='object')

# %%
model = SentenceTransformer('all-MiniLM-L6-v2', device='cpu')

# %%
subjects = [t if (isinstance(t, str) and t is not None) else '' for t in bill_text.loc[bill_text['bill_id'].str.startswith('2')]['general_subject'].tolist()]
embeddings = model.encode(
    subjects,
    batch_size=100,
    show_progress_bar=True,
    convert_to_tensor=True,
    num_workers=5,
    normalize_embeddings=False
)
# Out:
# Batches:   0%|          | 0/1702 [00:00<?, ?it/s]

# %%
lobbying_firms_embeddings = {}
for firm in lobbying.loc[(lobbying['clean_beneficiary'].notna()) & (lobbying['FIRM_NAME'].apply(lambda x: isinstance(x, str)))]['FIRM_NAME'].unique().tolist():
    lobbying_firms_embeddings[firm] = model.encode(firm)

# %%
committee_embeddings = {}
for committee in politicians['committee_clean'].unique().tolist():
    committee_embeddings[committee] = model.encode(committee)

# %%
import networkx as nx

# %%
legislators = politicians['full_name'].unique().tolist()

# %%
bills= bill_history.loc[bill_history['year'] > 1999]['bill_id'].unique().tolist()

# %%
bill_versions = [re.sub(r'_', '', b) for b in bill_text.loc[bill_text['bill_id'].str.startswith('2')]['bill_id'].unique().tolist()]

# %%
G = nx.MultiDiGraph()
